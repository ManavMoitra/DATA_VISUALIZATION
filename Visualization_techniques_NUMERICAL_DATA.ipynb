# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(5,100,100)
y=np.linspace(10,1000,100)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.xlabel("CURRENT") 
plt.ylabel("Voltage")
plt.title("Ohm's law")




plt.xlim([20,80])
plt.ylim([200,800])
plt.show()

# %%
x=np.linspace(0,10,20)
y=x*2
plt.plot(x,y,"b+")
plt.xlabel("CURRENT")
plt.ylabel("Voltage")
plt.title("Ohm's law")
# Out:
# Text(0.5, 1.0, "Ohm's law")

# %%
x=np.linspace(0,5,10)
y=np.linspace(3,6,10)
plt.plot(x,2*y,'r-',x,y**2,'b+',x,y**3,'g^')
plt.show()

# %%
x=np.linspace(1,10,100)
y=np.log(x)
plt.figure(1)

plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("y=log(x)")

plt.subplot(1,2,2)
plt.plot(x,y**2)
plt.title("y=log(x)**2")
# Out:
# Text(0.5, 1.0, 'y=log(x)**2')

# %%
x=np.linspace(1,50,100)


plt.figure(1)

plt.subplot(2,2,1)
plt.plot(x,x)


plt.subplot(2,2,2)
plt.plot(x,x**2)


plt.figure(2)

plt.subplot(2,2,1)
plt.plot(x,np.log(x))


plt.subplot(2,2,2)
plt.plot(x,np.exp(x))

# %%
df=pd.read_csv(r"C:\Users\KIIT\Desktop\iot images\market_fact.csv")
df.head(5)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
df.rename(columns={'Ord_id':'ord_id'},inplace='True')

# %%
df.head(5)
# Out:
#      ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
plt.boxplot(df['Order_Quantity'])
plt.show()

# %%
plt.boxplot(df['Sales'])
plt.show()

# %%
 
plt.subplot(1,2,1)
plt.boxplot(df['Sales'])

plt.subplot(1,2,2)
plt.boxplot(df['Sales'])
plt.yscale('log')
plt.plot()
# Out:
# []

# %%
plt.hist(df['Sales'])
plt.show()

# %%
plt.hist(df['Sales'])
plt.yscale('log')
plt.show()

# %%
import seaborn as sns
sns.set_style('whitegrid')

# %%
sns.distplot(df['Shipping_Cost'])
plt.show()

# %%
sns.distplot(df['Shipping_Cost'][:200],rug=True)
plt.show()

# %%
sns.distplot(df["Shipping_Cost"],hist=False)
plt.show()

# %%
plt.figure(1)
plt.subplot(2,2,1)
sns.distplot(df['Shipping_Cost'])
plt.title("Shipping Cost")


plt.subplot(2,2,2)
sns.distplot(df['Order_Quantity'])
plt.title('order quantity')
#
plt.figure(2)
plt.subplot(2,2,1)
sns.distplot(df['Sales'])
plt.title('Sales')

plt.subplot(2,2,2)
sns.distplot(df['Profit'])
plt.title("Profit")
# Out:
# Text(0.5, 1.0, 'Profit')

# %%
#BOXPLOT

sns.boxplot(y=df['Order_Quantity'])
plt.title("Order_Quantity")
plt.show()

# %%
#ANALYSIS FOR BIVARIATE DISTRIBUTIONS
sns.jointplot('Sales','Profit',data=df)
plt.show()

# %%
df1=df[(df.Profit<10000) &(df.Sales<20000)]
sns.jointplot('Sales','Profit',df1)
plt.plot()
# Out:
# []

# %%
df1=df[(df.Profit<100) & (df.Profit>-100) & (df.Sales<200)]
sns.jointplot(x=df1['Sales'],y=df1['Profit'],data=df1,kind="hex",color='k')
plt.show()

# %%
btc=pd.read_csv("bitcoin_price.csv")
ether=pd.read_csv("ethereum_price.csv")
ltc=pd.read_csv("litecoin_price.csv")
monero=pd.read_csv("monero_price.csv")
neo=pd.read_csv("neo_price.csv")
quantum=pd.read_csv("qtum_price.csv")
ripple=pd.read_csv("ripple_price.csv")


#PUTTING A SUFFIX WITH COLUMN NAMES SO  THAT JOINING BECOMES EASY
btc.columns=btc.columns.map(lambda x:str(x)+'_btc')
ether.columns=ether.columns.map(lambda x:str(x)+'_ether')
ltc.columns=ltc.columns.map(lambda x:str(x)+'_ltc')
monero.columns=monero.columns.map(lambda x:str(x)+'_mon')
neo.columns=neo.columns.map(lambda x:str(x)+'_neo')
quantum.columns=quantum.columns.map(lambda x:str(x)+'_qt')
ripple.columns=ripple.columns.map(lambda x:str(x)+'_rip')


btc.head()
# Out:
#        Date_btc  Open_btc  High_btc  Low_btc  Close_btc     Volume_btc  \
# 0  Nov 07, 2017   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1  Nov 06, 2017   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2  Nov 05, 2017   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3  Nov 04, 2017   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4  Nov 03, 2017   7087.53   7461.29  7002.94    7207.76  3,369,860,000
#
#     Market Cap_btc
# 0  117,056,000,000
# 1  123,379,000,000
# 2  123,388,000,000
# 3  119,376,000,000
# 4  118,084,000,000

# %%
m1=pd.merge(btc,ether,how='inner',left_on='Date_btc',right_on='Date_ether')
m2=pd.merge(m1,ltc,how='inner',left_on='Date_btc',right_on='Date_ltc')
m3=pd.merge(m2,monero,how='inner',left_on='Date_btc',right_on='Date_mon')
m4=pd.merge(m3,neo,how='inner',left_on='Date_btc',right_on='Date_neo')
m4.head(5)
# Out:
#        Date_btc  Open_btc  High_btc  Low_btc  Close_btc     Volume_btc  \
# 0  Nov 07, 2017   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1  Nov 06, 2017   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2  Nov 05, 2017   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3  Nov 04, 2017   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4  Nov 03, 2017   7087.53   7461.29  7002.94    7207.76  3,369,860,000
#
#     Market Cap_btc    Date_ether  Open_ether  High_ether  ...  Close_mon  \
# 0  117,056,000,000  Nov 07, 2017      298.57      304.84  ...      99.76
# 1  123,379,000,000  Nov 06, 2017      296.43      305.42  ...     102.92
# 2  123,388,000,000  Nov 05, 2017      300.04      301.37  ...      86.35
# 3  119,376,000,000  Nov 04, 2017      305.48      305.48  ...      87.30
# 4  118,084,000,000  Nov 03, 2017      288.50      308.31  ...      87.99
#
#     Volume_mon Market Cap_mon      Date_neo Open_neo  High_neo  Low_neo  \
# 0   81,253,300  1,596,750,000  Nov 07, 2017    26.26     26.52    25.62
# 1  103,722,000  1,323,540,000  Nov 06, 2017    26.47     26.81    25.95
# 2   27,619,800  1,336,790,000  Nov 05, 2017    26.48     26.72    25.79
# 3   23,011,500  1,345,360,000  Nov 04, 2017    26.77     27.74    25.94
# 4   37,321,100  1,278,080,000  Nov 03, 2017    24.60     26.90    24.39
#
#    Close_neo  Volume_neo Market Cap_neo
# 0      26.23  40,146,900  1,706,600,000
# 1      26.32  26,798,400  1,720,760,000
# 2      26.38  25,229,700  1,721,090,000
# 3      26.49  31,870,600  1,739,980,000
# 4      26.82  40,142,100  1,598,960,000
#
# [5 rows x 35 columns]

# %%
m5=pd.merge(m4,quantum,how='inner',left_on='Date_btc',right_on='Date_qt')
crypto=pd.merge(m5,ripple,how='inner',left_on='Date_btc',right_on='Date_rip')

# %%
curr=crypto[['Close_btc','Close_ether','Close_mon','Close_neo','Close_qt','Close_rip']]

# %%
curr.head()
# Out:
#    Close_btc  Close_ether  Close_mon  Close_neo  Close_qt  Close_rip
# 0    7144.38       294.66      99.76      26.23     11.21   0.210354
# 1    7022.76       298.89     102.92      26.32     10.44   0.205990
# 2    7407.41       296.26      86.35      26.38     10.13   0.202055
# 3    7379.95       300.47      87.30      26.49     10.05   0.203750
# 4    7207.76       305.71      87.99      26.82     10.38   0.208133

# %%
sns.pairplot(curr)

# %%
cor=curr.corr()
round(cor,3)
# Out:
#              Close_btc  Close_ether  Close_mon  Close_neo  Close_qt  Close_rip
# Close_btc        1.000        0.449      0.697      0.735     0.382     -0.198
# Close_ether      0.449        1.000      0.539      0.482     0.791      0.332
# Close_mon        0.697        0.539      1.000      0.669     0.518     -0.086
# Close_neo        0.735        0.482      0.669      1.000     0.557     -0.375
# Close_qt         0.382        0.791      0.518      0.557     1.000      0.292
# Close_rip       -0.198        0.332     -0.086     -0.375     0.292      1.000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(cor,cmap="YlGnBu",annot=True)
plt.show()

# %%
#PLOTTING CATEGORICAL VARIABLES ON Y_AXIS
plt.figure(figsize=(10,8))
